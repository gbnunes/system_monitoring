# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('./df_info.csv')

# %%
df.head()
# Out:
#    Geral  cpu_0  cpu_1  cpu_2  cpu_3  Memoria  SWAP  Temperatura  \
# 0   25.0    2.5    4.9    4.9   68.3     79.4  65.6         41.0
# 1   33.3    2.2    1.7   63.5    4.5     79.5  65.6         42.0
# 2   25.0   66.5    3.0    2.4    1.8     79.5  65.6         47.0
# 3   40.0   66.1    4.1    4.1    1.2     79.4  65.6         45.0
# 4   50.0    1.8    2.9   66.9    4.7     79.5  65.6         43.0
#
#    Temperatura acpitz Battery                     Date
# 0                27.8       -  Friday 08 July 22 04:14
# 1                27.8       -  Friday 08 July 22 04:14
# 2                27.8       -  Friday 08 July 22 04:14
# 3                27.8       -  Friday 08 July 22 04:14
# 4                27.8       -  Friday 08 July 22 04:14

# %%
fig, ax = plt.subplots(figsize=(12,12))
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(10,8))
new_df = df[['Geral','cpu_0','cpu_1','cpu_2','cpu_3']]
sns.boxplot(data=new_df)
# Out:
# <AxesSubplot:>

# %%
df_temp0 = df[['Temperatura']]
df_temp1 = df[['Temperatura acpitz']]

f, axes = plt.subplots(1, 2,figsize=(10,8))

sns.boxplot(data=df_temp0,  orient='v' , ax=axes[0])
sns.boxplot(data=df_temp1,  orient='v' , ax=axes[1])
# Out:
# <AxesSubplot:>

# %%
df_temp0 = df[['Memoria']]
df_temp1 = df[['SWAP']]

f, axes = plt.subplots(1, 2,figsize=(10,8))

sns.boxplot(data=df_temp0,  orient='v' , ax=axes[0])
sns.boxplot(data=df_temp1,  orient='v' , ax=axes[1])
# Out:
# <AxesSubplot:>

# %%
new_df = df[['Geral','cpu_0','cpu_1','cpu_2','cpu_3']]
plt.figure(figsize=(10,8))

sns.lineplot(data=new_df)
# Out:
# <AxesSubplot:>

# %%
new_df = df[['Temperatura','Temperatura acpitz']]
plt.figure(figsize=(10,8))

sns.lineplot(data=new_df)
# Out:
# <AxesSubplot:>
