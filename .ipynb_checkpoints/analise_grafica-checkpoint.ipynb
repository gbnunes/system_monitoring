# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('./df_info.csv')

# %%
df.head()
# Out:
#    Geral  cpu_0  cpu_1  cpu_2  cpu_3  Memoria  SWAP  Temperatura  \
# 0   40.0   31.7   26.9   29.8   89.3     79.8  31.1         51.0
# 1   60.0   26.7   28.7   28.0   72.4     79.8  31.1         50.0
# 2   75.0   33.3   32.0   26.2   74.0     80.0  31.1         51.0
# 3   80.0   67.0   68.0   85.1   69.1     80.3  31.1         51.0
# 4    0.0   53.3   82.3   56.7   49.2     80.1  31.1         53.0
#
#    Temperatura acpitz Battery                     Date
# 0                27.8       -  Friday 08 July 22 11:25
# 1                27.8       -  Friday 08 July 22 11:25
# 2                27.8       -  Friday 08 July 22 11:25
# 3                27.8       -  Friday 08 July 22 11:25
# 4                27.8       -  Friday 08 July 22 11:25

# %%
fig, ax = plt.subplots(figsize=(12,12))
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(10,8))
new_df = df[['Geral','cpu_0','cpu_1','cpu_2','cpu_3']]
sns.boxplot(data=new_df)
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(10,8))
sns.boxplot(data=df[['Memoria']])
# Out:
# <AxesSubplot:>
